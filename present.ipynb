# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from src import heston, simulation

# %%
v,x = simulation.gen_vol_sequence(0.01, 2, 0.01,0.1, 0.01,0.7, 0.0001, 0.5)
plt.plot(range(len(x)), 100*np.exp(x))

# %%
sns.displot(100*np.exp(x), kind="kde")

# %%
plt.plot(range(len(v)), v)

# %%
sns.pairplot(data=pd.DataFrame(np.array([x,v]).T))

# %%
call_price = heston.heston_price(1, 100, 100, 0.01, 0.5, 2, 0.01, 0.1, 0.01, 0.7, 0.00001, 50, 0.002)
put_price = heston.heston_price(0, 100, 100, 0.01, 0.5, 2, 0.01, 0.1, 0.01, 0.7, 0.00001, 50, 0.002)

# %%
und_price,payoff,call_option_price = simulation.gen_option_price(100, 100, 0.01, 0.5, 2,0.01,0.1,0.01,0.7,0.0001,1000)

# %%
print('From Heston:{:.2f}'.format(call_price))
print("Via Simulation:{:.2f}".format(call_option_price))
# Out:
# From Heston:3.03
# Via Simulation:2.98

# %%
sns.displot(und_price,  kind = "kde")
